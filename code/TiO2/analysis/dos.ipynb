# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
    df_dos = pd.read_csv('DOSCAR', header=None, skiprows=6, delim_whitespace=True)

# %%
fig = plt.figure(figsize=(16,20))
ax = fig.add_subplot()
ax.grid()
ax.plot(df_dos[0], df_dos[1])
