# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
    df_dos = pd.read_csv('DOSCAR_U', header=None, skiprows=6, delim_whitespace=True, nrows=301)
    fermi = 5.73260578

# %%
fig = plt.figure(figsize=(16,20))
ax = fig.add_subplot()
ax.grid()
ax.plot(df_dos[0]-fermi, df_dos[1])
ax.set_xlim(-10,10)
# Out:
# (-10.0, 10.0)
