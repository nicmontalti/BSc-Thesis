# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('REFORMATTED_BAND.dat', delim_whitespace=True)
df_labels = pd.read_csv('KLABELS', delim_whitespace=True)

# %%
df_labels

xlabel = df_labels['Coordinate']
labels = df_labels['K-Label']

# %%
x = df['#K-Path']
df = df.drop('#K-Path', axis=1)

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot()

ax.plot(x, df)
for xlab in xlabel:
    ax.axvline(xlab, color='black')
